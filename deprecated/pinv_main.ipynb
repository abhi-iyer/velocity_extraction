# %%
# %load_ext autoreload
# %autoreload 2

from imports import *

from models import *
from data import *
from utils import *

from pinv_configs import PINV_CONFIGS
from pinv_experiment import *

# %%
def show_all(exp_name, train):
    exp = PINV_Experiment(exp_name, PINV_CONFIGS[exp_name])
    exp.plot()
    _ = visualize(exp, train=train, verbose=True)
    cluster_velocities(exp, train=train)

# %%
count_parameters(PINV_RAND_vflat_LR())
# Out:
# 146202

# %%
# shift1_1 = PINV_Experiment(experiment_name="shift1_1", config=PINV_CONFIGS["shift1_1"])
# shift1_1.plot()

# shift10 = PINV_Experiment(experiment_name="shift10", config=PINV_CONFIGS["shift10"])
# shift10.plot()

# shift20 = PINV_Experiment(experiment_name="shift20", config=PINV_CONFIGS["shift20"])
# shift20.plot()

# shift1_2 = PINV_Experiment(experiment_name="shift1_2", config=PINV_CONFIGS["shift1_2"])
# shift1_2.plot()

# %%
show_all("shift1_rand_vflat_combine_tripletdiv", train=False)
# Out:
# Difference between I1 and I2: 97.57849884033203
# Difference between I1 and reconstructed: 104.62123107910156
# Difference between I2 and reconstructed: 98.27059173583984
# Testing Loss: 93.92987823486328
# Predicted velocity: [-0.56344163 -0.78827643]
# Ground truth velocity: [1. 1.]

# %%
show_all("shift1_rand_vflat_combine_tripletsub", train=False)
# Out:
# Difference between I1 and I2: 112.63533020019531
# Difference between I1 and reconstructed: 146.0940399169922
# Difference between I2 and reconstructed: 94.49870300292969
# Testing Loss: 48.4046630859375
# Predicted velocity: [-0.56455797 -0.35662562]
# Ground truth velocity: [1. 1.]

# %%
show_all("shift1_rand_vflat_LR_tripletdiv", train=False)
# Out:
# Difference between I1 and I2: 94.02022552490234
# Difference between I1 and reconstructed: 118.88321685791016
# Difference between I2 and reconstructed: 100.13806915283203
# Testing Loss: 84.2322998046875
# Predicted velocity: [-0.49039677 -0.21336113]
# Ground truth velocity: [0. 1.]

# %%
show_all("shift1_rand_vflat_LR_tripletsub", train=False)
# Out:
# Difference between I1 and I2: 111.62043762207031
# Difference between I1 and reconstructed: 122.67347717285156
# Difference between I2 and reconstructed: 41.43075942993164
# Testing Loss: 18.757287979125977
# Predicted velocity: [ 0.27860403 -0.433989  ]
# Ground truth velocity: [-1.  1.]

# %%
# dataset = shift1_2.train_loader.dataset
# sample = dataset[torch.randint(0, len(dataset), size=(1,)).item()]

# SSIM_Loss(data_range=1.0, channel=1)(sample[0].unsqueeze(0), sample[1].unsqueeze(0))

# %%
# show_all("shift5_LR_tripletdiv", train=True)
# show_all("shift5_LR_regloss", train=True)
# show_all("shift5_combine_tripletdiv", train=True)
# show_all("shift5_combine_regloss", train=True)
#show_all("shift5_LR_cropregloss", train=True)
# show_all("shift5_LR_croptripletdiv", train=True)
# show_all("shift5_combine_cropregloss", train=True)
# show_all("shift5_combine_croptripletdiv", train=True)

# %%
show_all("shift1_rand_combine_croptripletdiv", train=False)
# Out:
# Difference between I1 and I2: 96.46671295166016
# Difference between I1 and reconstructed: 99.7292709350586
# Difference between I2 and reconstructed: 109.83882141113281
# Testing Loss: 109.08241271972656
# Predicted velocity: [-1.2603806  -0.20195684]
# Ground truth velocity: [0. 1.]

# %%
show_all("shift1_rand_LR_croptripletdiv", train=False)
# Out:
# Difference between I1 and I2: 106.48091125488281
# Difference between I1 and reconstructed: 116.28816223144531
# Difference between I2 and reconstructed: 96.82435607910156
# Testing Loss: 88.55945587158203
# Predicted velocity: [-1.4175189  -0.87849164]
# Ground truth velocity: [ 1. -1.]

# %%
shift1_rand_vflat_LR_regloss = PINV_Experiment("shift1_rand_vflat_LR_regloss", PINV_CONFIGS["shift1_rand_vflat_LR_regloss"])
model = shift1_rand_vflat_LR_regloss.model

# %%
dataset = RandomPairs(train=True, image_size=(320, 320), patch_size=(16, 16), eps_shift=1)
sample = dataset[torch.randint(0, len(dataset), size=(1,)).item()]
print(sample[2])
# Out:
# tensor([1., 1.])

# %%
model.eval()

v = model.get_v(sample[0].cuda(), sample[1].cuda())

L = model.A_v_L(v).reshape(-1,  16, 16)
R = model.A_v_R(v).reshape(-1,  16, 16)

# %%
imshow_gray(L.squeeze())

# %%
imshow_gray(R.squeeze())

# %%
show_all("shift1_rand_LR_cropregloss", train=False)
# Out:
# Difference between I1 and I2: 96.6575927734375
# Difference between I1 and reconstructed: 103.84201049804688
# Difference between I2 and reconstructed: 76.81239318847656
# Testing Loss: 82.29961395263672
# Predicted velocity: [-0.17037457 -0.4166007 ]
# Ground truth velocity: [ 1. -1.]

# %%
show_all("shift1_rand_vflat_combine_regloss", train=False)
# Out:
# Difference between I1 and I2: 98.53327178955078
# Difference between I1 and reconstructed: 105.6025161743164
# Difference between I2 and reconstructed: 104.73512268066406
# Testing Loss: 104.73512268066406
# Predicted velocity: [-0.13190962 -0.56684995]
# Ground truth velocity: [-1.  0.]

# %%
show_all("shift1_rand_vflat_LR_regloss", train=False)
# Out:
# Difference between I1 and I2: 85.77645874023438
# Difference between I1 and reconstructed: 103.7225341796875
# Difference between I2 and reconstructed: 98.02833557128906
# Testing Loss: 98.02833557128906
# Predicted velocity: [-2.6005826  1.0854412]
# Ground truth velocity: [-1. -1.]

# %%
show_all("shift1_rand_combine_cropregloss", train=True)
# Out:
# Difference between I1 and I2: 99.07754516601562
# Difference between I1 and reconstructed: 101.8635482788086
# Difference between I2 and reconstructed: 26.695650100708008
# Training Loss: 20.614212036132812
# Predicted velocity: [ 1.0603787 -0.3651633]
# Ground truth velocity: [-1. -1.]
