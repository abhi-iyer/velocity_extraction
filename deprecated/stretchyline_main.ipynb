# %%
# %load_ext autoreload
# %autoreload 2

from imports import *

from models import *
from data import *
from utils import *

from stretchyline_configs import STRETCHYLINE_CONFIGS
from stretchyline_experiment import *

# %%
def show_all_stretchyline(exp_name, train):
    exp = StretchyLine_Experiment(exp_name, STRETCHYLINE_CONFIGS[exp_name])
    exp.plot()
    _ = visualize_stretchyline(exp, train=train, verbose=True)
    cluster_velocities_stretchyline(exp, train=train)
    cluster_fixed_velocities_stretchyline(exp, train=train)

# %%
show_all_stretchyline("shift5_unfixedshift_A1_mse", train=True)

# %%
show_all_stretchyline("shift5_fixedshift_A1_mse", train=True)

# %%
show_all_stretchyline("shift5_unfixedshift_LR1_mse", train=False)
# Out:
# Number of model parameters: 34836
# Difference between I1 and I2: 4.130297660827637
# Difference between I1 and reconstructed: 37.159027099609375
# Difference between I2 and reconstructed: 38.69938659667969
# Testing Loss: 0.004940035752952099
# Predicted velocity: [-0.34818774 -1.9375393 ]
# Ground truth velocity: [ 4. -3.]

# %%
show_all_stretchyline("shift5_fixedshift_LR1_mse", train=False)
# Out:
# Number of model parameters: 34836
# Difference between I1 and I2: 2.06679105758667
# Difference between I1 and reconstructed: 35.25712585449219
# Difference between I2 and reconstructed: 35.08353805541992
# Testing Loss: 0.0019577962812036276
# Predicted velocity: [-0.2432804 -0.8883538]
# Ground truth velocity: [ 0. -5.]

# %%
show_all_stretchyline("shift5_unfixedshift_A1_ssim", train=True)

# %%
show_all_stretchyline("shift5_fixedshift_A1_ssim", train=False)

# %%
show_all_stretchyline("shift5_unfixedshift_A2_mse", train=False)
# Out:
# Number of model parameters: 108155
# Difference between I1 and I2: 2.7722299098968506
# Difference between I1 and reconstructed: 2.7766406536102295
# Difference between I2 and reconstructed: 0.01118779182434082
# Testing Loss: 4.8285862419561454e-08
# Predicted velocity: [-0.54351664  0.24149242]
# Ground truth velocity: [ 1. -3.]

# %%
show_all_stretchyline("shift5_fixedshift_A2_mse", train=False)
# Out:
# Number of model parameters: 108155
# Difference between I1 and I2: 5.562406539916992
# Difference between I1 and reconstructed: 5.552542209625244
# Difference between I2 and reconstructed: 0.037854909896850586
# Testing Loss: 1.4261139824611746e-07
# Predicted velocity: [-1.5622051  0.9594935]
# Ground truth velocity: [ 5. -5.]

# %%
show_all_stretchyline("shift5_unfixedshift_A2_ssim", train=False)
# Out:
# Number of model parameters: 108155
# Difference between I1 and I2: 3.78420352935791
# Difference between I1 and reconstructed: 3.783947229385376
# Difference between I2 and reconstructed: -1.1920928955078125e-05
# Testing Loss: -1.1920928955078125e-05
# Predicted velocity: [-0.34012616  0.44889897]
# Ground truth velocity: [ 4. -2.]

# %%
show_all_stretchyline("shift5_fixedshift_A2_ssim", train=False)
# Out:
# Number of model parameters: 108155
# Difference between I1 and I2: 4.611611366271973
# Difference between I1 and reconstructed: 2.5710761547088623
# Difference between I2 and reconstructed: 2.07708477973938
# Testing Loss: 2.07708477973938
# Predicted velocity: [-0.1874024 -1.2118962]
# Ground truth velocity: [-5.  5.]
